# %%
import random

# %% [markdown]
# ### Problem Statement:-
#
# 1. Generate a random integer from a to b.
# 2. You and your friend have to guess a number between two numbers, a and b.
# 3. a and b should be inputs taken from the user only.
#
# Your friend is player 1 and plays first. He will have to keep choosing the number, and your program must tell whether the number is greater than the actual number or less than the actual number. Log the number of trials it took your friend to arrive at the number.
#
# You play the same game, and then the person with the minimum number of trials wins!
# Randomly generate a number after taking a and b as input and don’t show that to the user.
#
# #### Input :
# Enter start (a) : 4
#
# Enter end (b) : 13
#
# #### Output :
# Player1 :
#
# Please guess the number between 4 and 13
#
# 5
#
# Wrong guess a greater number again
#
# 8
#
# Wrong guess a smaller number again
#
# 6
#
# Correct, you took 3 trials to guess the number
#
# Player 2:
#
# Correct, you took 7 trials to guess the number
#
# Player 1 wins!

# %% [markdown]
# ### My initial take

# %%
a = int(input("Enter your start : "))
b = int(input("Enter your end : "))
actual_number = int(input(f"Imagine any number between {a} and {b} : "))
trials = 1

for i in range(a,b):
    guess = int(input(f"Please guess any number between {a} and {b} : "))
    while guess != actual_number:
        if guess < actual_number:
            print("Ah ! Wrong guess. The number you've guessed is smaller. please try again.")
            trials += 1
            break
        elif guess > actual_number:
            print("Ah ! Wrong guess. The number you've guessed is greater. please try again.")
            trials +=1
            break
    if guess == actual_number:
        print(f"Correct! You took {trials} trials to guess the right number.")
        break

# %% [markdown]
# ### Solution on Code with Harry

# %%
import random

# defining the rules of our game
def guess_game(a, b, actual):
    guess = int(input(f"Guess a number between {a} and {b} : \n"))
    trials = 1
    
    while guess != actual:
        if guess < actual:
            guess = int(input("Wrong! Enter a bigger number :- \n"))
            trials +=1
        else:
            guess = int(input("Wrong! Enter a smaller number :- \n"))
            trials +=1
            
    print(f"You've guessed the right number after {trials} gueses.", end = "\n\n")
    return trials

# this will declare the range 
a = int(input("Enter start :- \n"))
b = int(input("Enter end :- \n"))

# to randomly choose any number between the given range
actual_1 = random.randint(a, b)
actual_2 = random.randint(a, b)

# game starts here
print("Player 1 turn :- ")
g1 = guess_game(a,b,actual_1)
print("Player 2 turn :- ")
g2 = guess_game(a,b,actual_2)

# final results
if g1 < g2:
    print("Player 1 won !")
elif g2 < g1:
    print("Player 2 won !")
else:
    ("Its a Draw !")
    
print(f"The number for 1st Player was {actual_1} and for 2nd Player was {actual_2}")
# Out:
# Enter start :-
# 10
# Enter end :-
# 20
# Player 1 turn :-
# Guess a number between 10 and 20 :
# 16
# Wrong! Enter a bigger number :-
# 18
# You've guessed the right number after 2 gueses.
#
# Player 2 turn :-
# Guess a number between 10 and 20 :
# 12
# You've guessed the right number after 1 gueses.
#
# Player 2 won !
# The number for 1st Player was 18 and for 2nd Player was 12

# %% [markdown]
# ### Making it more dynamic

# %%
import random

print("Welcome to 'Guess the Number!' \n")

# defining the rules
def guess_game(a, b, actual):
    
    trial_no = 1
    chances = 6
    
    while chances >= 6:
        guess = int(input(f"Guess a number between {a} and {b} : \n{chances} chances left! \n"))
        while guess != actual:
            if chances == 1:
                print("No chances left! Game Over !")
                break
                
            if chances == 2:
                chances -=1
                guess = int(input(f"Wrong! Enter a bigger number :- \nCareful, last chance!\n"))
                trial_no +=1
                if guess != actual:
                    if chances == 1:
                        print("No chances left. Game Over. \n")
                        break
                else:
                    print(f"You've guessed the right number after {trial_no} gueses.", end = "\n")
                    
            if guess < actual:
                chances -=1
                guess = int(input(f"Wrong! Enter a bigger number :- \n{chances} chances left! \n"))
                trial_no +=1
                      
            elif guess > actual:
                chances -=1
                guess = int(input(f"Wrong! Enter a smaller number :- \n{chances} chances left! \n"))
                trial_no +=1
        
        print(f"\nYou took {trial_no} trial/s \n") 
        
    return trial_no

# this will declare the range 
a = int(input("Enter start :- \n"))
b = int(input("Enter end :- \n"))

# to randomly choose any number between the given range
actual_1 = random.randint(a, b)
actual_2 = random.randint(a, b)

# game starts here
print("\nPlayer 1 turn :- ")
g1 = guess_game(a,b,actual_1)
print("Player 2 turn :- ")
g2 = guess_game(a,b,actual_2)

# final results
if g1 < g2:
    print("Player 1 won!")
elif g2 < g1:
    print("Player 2 won!")
else:
    ("Its a Draw !")
    
print(f"The number for 1st Player was {actual_1} and for 2nd Player was {actual_2}.")
# Out:
# Welcome to 'Guess the Number!'
# Enter start :-
# 10
# Enter end :-
# 20
# Player 1 turn :-
# Guess a number between 10 and 20 :
# 6 chances left!
# 11
# Wrong! Enter a bigger number :-
# 5 chances left!
# 15
# Wrong! Enter a smaller number :-
# 4 chances left!
# 13
# Player 2 turn :-
# Guess a number between 10 and 20 :
# 6 chances left!
# 11
# Wrong! Enter a bigger number :-
# 5 chances left!
# 12
# Wrong! Enter a bigger number :-
# 4 chances left!
# 13
# Wrong! Enter a bigger number :-
# 3 chances left!
# 15
# Player 1 won !
# The number for 1st Player was 13. and for 2nd Player was 15.

# %% [markdown]
# ### Some extra features

# %%
import random

print("Welcome to 'Guess the Number!' \n")

#4. player1 turn
def guess_game1(a, b, actual):
    player_1_trial = 1
    chances = 6
    
    while chances >= 6:
        guess = int(input(f"Guess a number between {a} and {b} : \n{chances} chances left! \n"))
        while guess != actual:
            if chances == 1:
                print("No chances left! Game Over !")
                break
                
            if chances == 2:
                chances -=1
                guess = int(input(f"Wrong! Enter a bigger number :- \nCareful, last chance!\n"))
                player_1_trial +=1
                if guess != actual:
                    if chances == 1:
                        print("\nNo chances left. Game Over. \n")
                        break
                else:
                    print("Woah! Ass saved! \n")
                    
            if guess < actual:
                chances -=1
                guess = int(input(f"Wrong! Enter a bigger number :- \n{chances} chances left! \n"))
                player_1_trial +=1
                      
            elif guess > actual:
                chances -=1
                guess = int(input(f"Wrong! Enter a smaller number :- \n{chances} chances left! \n"))
                player_1_trial +=1
        
        print(f"\nYou took {player_1_trial} trial/s. \n") 
        
    trial1.append(player_1_trial)

#5. player 2 turn
def guess_game2(a, b, actual):
    
    player_2_trial = 1
    chances = 6
    
    while chances >= 6:
        guess = int(input(f"Guess a number between {a} and {b} : \n{chances} chances left! \n"))
        while guess != actual:
            if chances == 1:
                print("No chances left! Game Over !")
                break
                
            if chances == 2:
                chances -=1
                guess = int(input(f"Wrong! Enter a bigger number :- \nCareful, last chance!\n"))
                player_2_trial +=1
                if guess != actual:
                    if chances == 1:
                        print("No chances left. Game Over. \n")
                        break
                else:
                    print("Woah! Ass saved! \n")
                    
            if guess < actual:
                chances -=1
                guess = int(input(f"Wrong! Enter a bigger number :- \n{chances} chances left! \n"))
                player_2_trial +=1
                      
            elif guess > actual:
                chances -=1
                guess = int(input(f"Wrong! Enter a smaller number :- \n{chances} chances left! \n"))
                player_2_trial +=1
        
        print(f"\nYou took {player_2_trial} trial/s. \n") 
        
    trial2.append(player_2_trial)


#1. this will declare the range 
a = int(input("Lets select your range first. \nYour range starts from :- \n"))
b = int(input("Enter end :- \n"))

#2. this will randomly choose any number between the given range. (backend)
actual_1 = random.randint(a, b)
actual_2 = random.randint(a, b)

# take names from players
name1 = input("Enter Name for Player 1 : \n")
name2 = input("Enter Name for Player 2 : \n")

# it will store the trials of each players
trial1 = []
trial2 = []

#3. game starts here
print(f"\n{name1.capitalize()}'s turn :- ")
g1 = guess_game1(a,b,actual_1)

print(f"{name2.capitalize()}'s turn :- ")
g2 = guess_game2(a,b,actual_2)

#6. final results
if trial1 < trial2:
    print(f"{name1.capitalize()} won!\n")
    
elif trial2 < trial1:
    print(f"{name2.capitalize()} won!\n")
    
elif trial1 == trial2:
    print("Its a Draw !")

print(f"{name1.capitalize()} took {trial1} trials.")
print(f"{name2.capitalize()} took {trial2} trials.")
print(f"The number for {name1.capitalize()} and {name2.capitalize()} was {actual_1} and {actual_2}.")
# Out:
# Welcome to 'Guess the Number!'
#
# Lets select your range first.
# Your range starts from :-
# 10
# Enter end :-
# 20
# Enter Name for Player 1 :
# Jayant
# Enter Name for Player 2 :
# Shubham
#
# Jayant's turn :-
# Guess a number between 10 and 20 :
# 6 chances left!
# 15
# Wrong! Enter a bigger number :-
# 5 chances left!
# 17
# Wrong! Enter a bigger number :-
# 4 chances left!
# 19
# Wrong! Enter a smaller number :-
# 3 chances left!
# 16
# Wrong! Enter a bigger number :-
# 2 chances left!
# 18
#
# You took 5 trial/s.
#
# Shubham's turn :-
# Guess a number between 10 and 20 :
# 6 chances left!
# 19
# Wrong! Enter a smaller number :-
# 5 chances left!
# 12
#
# You took 2 trial/s.
#
# Shubham won!
#
# Jayant took [5] trials.
# Shubham took [2] trials.
# The number for Jayant and Shubham was 18 and 12.

# %% [markdown]
# ### To make it even more dynamic :
#
# 1. Give chances according to the range entered by the users.
# 2. Ask how many players are there.
